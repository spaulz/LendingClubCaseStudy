# %%
import pandas as pd
import numpy as np
import seaborn as sn

# %%
file= pd.read_csv('loan.csv')
# Out:
# C:\Users\SUDEEPz\AppData\Local\Temp\ipykernel_21176\2141038351.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   file= pd.read_csv('loan.csv')

# %%
file.head()
pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows', 100)
file.head(10)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
# 5  1075269    1311441       5000         5000           5000.0   36 months
# 6  1069639    1304742       7000         7000           7000.0   60 months
# 7  1072053    1288686       3000         3000           3000.0   36 months
# 8  1071795    1306957       5600         5600           5600.0   60 months
# 9  1071570    1306721       5375         5375           5350.0   60 months
#
#   int_rate  installment grade sub_grade                  emp_title emp_length  \
# ...

# %%
file.shape
# Out:
# (39717, 111)

# %%
file.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
file.info(all)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 111 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    id                              int64
#  1    member_id                       int64
#  2    loan_amnt                       int64
#  3    funded_amnt                     int64
#  4    funded_amnt_inv                 float64
#  5    term                            object
#  6    int_rate                        object
#  7    installment                     float64
#  8    grade                           object
#  9    sub_grade                       object
#  10   emp_title                       object
#  11   emp_length                      object
#  12   home_ownership                  object
#  13   annual_inc                      float64
#  14   verification_status             object
#  15   issue_d                         object
# ...

# %% [markdown]
# ## droping columns which are of no use and having Null values

# %%
file=file.drop('total_il_high_credit_limit',axis=1)

# %%
file.info(all)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 110 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    id                              int64
#  1    member_id                       int64
#  2    loan_amnt                       int64
#  3    funded_amnt                     int64
#  4    funded_amnt_inv                 float64
#  5    term                            object
#  6    int_rate                        object
#  7    installment                     float64
#  8    grade                           object
#  9    sub_grade                       object
#  10   emp_title                       object
#  11   emp_length                      object
#  12   home_ownership                  object
#  13   annual_inc                      float64
#  14   verification_status             object
#  15   issue_d                         object
# ...

# %%
file.total_bc_limit.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 39717 entries, 0 to 39716
# Series name: total_bc_limit
# Non-Null Count  Dtype
# --------------  -----
# 0 non-null      float64
# dtypes: float64(1)
# memory usage: 310.4 KB

# %%
file.total_bc_limit.unique()
# Out:
# array([nan])

# %%
file=file.drop('total_bc_limit',axis=1)

# %%
file.info(all)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 109 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    id                              int64
#  1    member_id                       int64
#  2    loan_amnt                       int64
#  3    funded_amnt                     int64
#  4    funded_amnt_inv                 float64
#  5    term                            object
#  6    int_rate                        object
#  7    installment                     float64
#  8    grade                           object
#  9    sub_grade                       object
#  10   emp_title                       object
#  11   emp_length                      object
#  12   home_ownership                  object
#  13   annual_inc                      float64
#  14   verification_status             object
#  15   issue_d                         object
# ...

# %%
file.isnull().sum()
# Out:
# id                          0
# member_id                   0
# loan_amnt                   0
# funded_amnt                 0
# funded_amnt_inv             0
#                         ...
# percent_bc_gt_75        39717
# pub_rec_bankruptcies      697
# tax_liens                  39
# tot_hi_cred_lim         39717
# total_bal_ex_mort       39717
# Length: 109, dtype: int64

# %%
file.info(all)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 109 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    id                              int64
#  1    member_id                       int64
#  2    loan_amnt                       int64
#  3    funded_amnt                     int64
#  4    funded_amnt_inv                 float64
#  5    term                            object
#  6    int_rate                        object
#  7    installment                     float64
#  8    grade                           object
#  9    sub_grade                       object
#  10   emp_title                       object
#  11   emp_length                      object
#  12   home_ownership                  object
#  13   annual_inc                      float64
#  14   verification_status             object
#  15   issue_d                         object
# ...

# %% [markdown]
# ## Removed all the columns with Null values

# %%
file=file.dropna(axis =1)

# %%
file.info(all)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 43 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       39717 non-null  int64
#  1   member_id                39717 non-null  int64
#  2   loan_amnt                39717 non-null  int64
#  3   funded_amnt              39717 non-null  int64
#  4   funded_amnt_inv          39717 non-null  float64
#  5   term                     39717 non-null  object
#  6   int_rate                 39717 non-null  object
#  7   installment              39717 non-null  float64
#  8   grade                    39717 non-null  object
#  9   sub_grade                39717 non-null  object
#  10  home_ownership           39717 non-null  object
#  11  annual_inc               39717 non-null  float64
#  12  verification_status      39717 non-null  object
#  13  issue_d                  39717 non-null  object
# ...

# %%
file.isnull().sum()
# Out:
# id                         0
# member_id                  0
# loan_amnt                  0
# funded_amnt                0
# funded_amnt_inv            0
# term                       0
# int_rate                   0
# installment                0
# grade                      0
# sub_grade                  0
# home_ownership             0
# annual_inc                 0
# verification_status        0
# issue_d                    0
# loan_status                0
# pymnt_plan                 0
# url                        0
# purpose                    0
# zip_code                   0
# addr_state                 0
# dti                        0
# delinq_2yrs                0
# earliest_cr_line           0
# inq_last_6mths             0
# open_acc                   0
# pub_rec                    0
# revol_bal                  0
# total_acc                  0
# initial_list_status        0
# out_prncp                  0
# out_prncp_inv              0
# total_pymnt                0
# ...
